# %%
# !pip install roboflow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="2X4JRhaChQhCtk06zZ9q")
project = rf.workspace().project("currency-v4f8j")
model = project.version(1).model
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# infer on a local image
print(model.predict("money2.jpg", confidence=25, overlap=30).json())

# visualize your prediction
model.predict("money2.jpg", confidence=25, overlap=30).save("prediction.jpg")
# Out:
# {'predictions': [{'x': 327.0, 'y': 248.5, 'width': 574.0, 'height': 271.0, 'confidence': 0.38068294525146484, 'class': 'ten', 'class_id': 8, 'image_path': 'money2.jpg', 'prediction_type': 'ObjectDetectionModel'}, {'x': 324.0, 'y': 248.0, 'width': 576.0, 'height': 272.0, 'confidence': 0.2761870324611664, 'class': 'fifty', 'class_id': 4, 'image_path': 'money2.jpg', 'prediction_type': 'ObjectDetectionModel'}], 'image': {'width': '640', 'height': '480'}}
